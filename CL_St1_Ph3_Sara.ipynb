# %% [markdown]
# <center>
# <img src="https://laelgelcpublic.s3.sa-east-1.amazonaws.com/lael_50_years_narrow_white.png.no_years.400px_96dpi.png" width="300" alt="LAEL 50 years logo">
# <h3>APPLIED LINGUISTICS GRADUATE PROGRAMME (LAEL)</h3>
# </center>
# <hr>

# %% [markdown]
# # Corpus Linguistics - Study 1 - Phase 2 - Sara

# %% [markdown]
# The purpose of this document is to generate short stories corresponding to the human-authored corpus using ChatGPT.

# %% [markdown]
# ## GPT Prompt Design and Text Generation Guidelines

# %% [markdown]
# ### 1. Prompt design
#
# #### A. Prompt the LLM to extract the plot from the human story
#
# ```
# =>
# 0001_plot.txt
# ```
#
# #### B. Prompt the LLM to provide a style profile for the human story
#
# ```
# =>
# 0001_style.txt
# ----------
# ```
#
# ### 2. Generation
#
# Use the plot and style information below to write a short story.
# 0001_plot.txt
# 0001_style.txt
#
# ```
# =>
# 0001_llm.txt
# ...
# 1000_llm.txt
# ----------
# ```

# %% [markdown]
# ## Required Python packages

# %% [markdown]
# - pandas

# %% [markdown]
# ## Importing the required libraries

# %%
import pandas as pd
import os
import sys

# %% [markdown]
# ## Define input variables

# %%
input_directory = 'cl_st1_ph2_sara'
output_directory = 'cl_st1_ph3_sara'
id = 'short_stories'
dataset_filename_1 = f"{id}_sample"

# %% [markdown]
# ## Create output directory

# %%
# Check if the output directory already exists. If it does, do nothing. If it doesn't exist, create it.
if os.path.exists(output_directory):
    print('Output directory already exists.')
else:
    try:
        os.makedirs(output_directory)
        print('Output directory successfully created.')
    except OSError as e:
        print('Failed to create the directory:', e)
        sys.exit(1)
# Out:
# Output directory successfully created.

# %% [markdown]
# ## Import the data into a DataFrame

# %%
df_short_stories_sample_balanced = pd.read_json(f"{input_directory}/{dataset_filename_1}.jsonl", lines=True)

# %%
df_short_stories_sample_balanced
# Out:
#       Unnamed: 0                                                url  length  \
# 0            692  https://americanliterature.com/author/ambrose-...    2478
# 1            667  https://americanliterature.com/author/ambrose-...    2430
# 2            671  https://americanliterature.com/author/ambrose-...    3221
# 3            697  https://americanliterature.com/author/ambrose-...    2883
# 4            687  https://americanliterature.com/author/ambrose-...    3247
# ...          ...                                                ...     ...
# 998         4019  https://americanliterature.com/author/william-...    2753
# 999         4020  https://americanliterature.com/author/william-...    2041
# 1000        4022  https://americanliterature.com/author/william-...    2700
# 1001        4023  https://americanliterature.com/author/william-...    2388
# 1002        4024  https://americanliterature.com/author/william-...    1942
#
# ...

# %% [markdown]
# ### erfsdf

# %%
df_short_stories_sample_balanced['file_id'] = 'f' + df_short_stories_sample_balanced.index.astype(str).str.zfill(6)

# %%
df_short_stories_sample_balanced
# Out:
#       Unnamed: 0                                                url  length  \
# 0            692  https://americanliterature.com/author/ambrose-...    2478
# 1            667  https://americanliterature.com/author/ambrose-...    2430
# 2            671  https://americanliterature.com/author/ambrose-...    3221
# 3            697  https://americanliterature.com/author/ambrose-...    2883
# 4            687  https://americanliterature.com/author/ambrose-...    3247
# ...          ...                                                ...     ...
# 998         4019  https://americanliterature.com/author/william-...    2753
# 999         4020  https://americanliterature.com/author/william-...    2041
# 1000        4022  https://americanliterature.com/author/william-...    2700
# 1001        4023  https://americanliterature.com/author/william-...    2388
# 1002        4024  https://americanliterature.com/author/william-...    1942
#
# ...

# %%
for index, row in df_short_stories_sample_balanced.iterrows():
    # Constructing the file name based on row data and index
    file_name = f"{output_directory}/{row['file_id']}.txt"

    # Writing the 'Short Story Text' content to the file
    with open(file_name, 'w', encoding='utf-8') as file:
        file.write(row['story'])
